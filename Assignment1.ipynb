# %% [markdown]
# <a href="https://colab.research.google.com/github/shindeaditya685/data-science-and-big-data-analysis/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
df = pd.read_csv("/content/my_dataset/autodata.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0  symboling  normalized-losses   make aspiration num-of-doors  \
# 196         196         -1                 95  volvo        std         four
# 197         197         -1                 95  volvo      turbo         four
# 198         198         -1                 95  volvo        std         four
# 199         199         -1                 95  volvo      turbo         four
# 200         200         -1                 95  volvo      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 196      sedan          rwd           front       109.1  ...
# 197      sedan          rwd           front       109.1  ...
# 198      sedan          rwd           front       109.1  ...
# 199      sedan          rwd           front       109.1  ...
# 200      sedan          rwd           front       109.1  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   100.000000    0.840796          122.00000   98.797015    0.837102
# std     58.167861    1.254802           31.99625    6.066366    0.059213
# min      0.000000   -2.000000           65.00000   86.600000    0.678039
# 25%     50.000000    0.000000          101.00000   94.500000    0.801538
# 50%    100.000000    1.000000          122.00000   97.000000    0.832292
# 75%    150.000000    2.000000          137.00000  102.400000    0.881788
# max    200.000000    3.000000          256.00000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean     0.915126   53.766667  2555.666667   126.875622    3.330692
# std      0.029187    2.447822   517.296727    41.546834    0.268072
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  aspiration  \
# 0         False      False              False  False       False
# 1         False      False              False  False       False
# 2         False      False              False  False       False
# 3         False      False              False  False       False
# 4         False      False              False  False       False
# ..          ...        ...                ...    ...         ...
# 196       False      False              False  False       False
# 197       False      False              False  False       False
# 198       False      False              False  False       False
# 199       False      False              False  False       False
# 200       False      False              False  False       False
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0           False       False         False            False       False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
df.notnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  aspiration  num-of-doors  \
# 0          True       True               True  True        True          True
# 1          True       True               True  True        True          True
# 2          True       True               True  True        True          True
# 3          True       True               True  True        True          True
# 4          True       True               True  True        True          True
# ..          ...        ...                ...   ...         ...           ...
# 196        True       True               True  True        True          True
# 197        True       True               True  True        True          True
# 198        True       True               True  True        True          True
# 199        True       True               True  True        True          True
# 200        True       True               True  True        True          True
#
# ...

# %%
df.notnull().sum()
# Out:
# Unnamed: 0           201
# symboling            201
# normalized-losses    201
# make                 201
# aspiration           201
# num-of-doors         201
# body-style           201
# drive-wheels         201
# engine-location      201
# wheel-base           201
# length               201
# width                201
# height               201
# curb-weight          201
# engine-type          201
# num-of-cylinders     201
# engine-size          201
# fuel-system          201
# bore                 201
# stroke               197
# compression-ratio    201
# horsepower           199
# peak-rpm             199
# city-mpg             201
# highway-mpg          201
# price                201
# city-L/100km         201
# horsepower-binned    199
# diesel               201
# gas                  201
# dtype: int64

# %%
#calculate the mean value for "stroke" column
#astype() function convert pandas object to a specified datatype
# axis = 0 refers to horizontal axis or rows
avg_stroke = df["stroke"].astype("float").mean(axis = 0)
print("Average of stroke: ", avg_stroke)
# Out:
# Average of stroke:  3.256903553299492

# %%
#replace NaN by mean value in "stroke" column
#When trying to make changes to a Pandas dataframe using a function, we use 'inplace=True' if we want to commit the changes to the dataframe.
df["stroke"].replace(np.nan, avg_stroke, inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
#Now we can the "stroke" which has no null values because we have replaced those value in above step now remained for "horsepower", "peak-rpm" and "horsepower-binned" etc.

#for "horsepower" calculate mean
avg_horsepower = df["horsepower"].astype("float").mean(axis = 0)
print("Average horsepower: ", avg_horsepower)

#now replace NaN values of horsepower column by "avg_horsepower"
df["horsepower"].replace(np.nan, avg_horsepower, inplace = True)
# Out:
# Average horsepower:  103.39698492462311

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
#Now we check in above output for horsepower column there is no NULL values .
#for "peak_rpm"

avg_peak_rpm = df["peak-rpm"].astype("float").mean(axis = 0)
print("Average peak_rpm: ", avg_peak_rpm)

#Now replace NULL/NaN values by "avg_peak_mean"
df["peak-rpm"].replace(np.nan, avg_peak_rpm, inplace = True)
# Out:
# Average peak_rpm:  5117.587939698493

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
#value_counts() categorizes the types of categories in that columns and tells the count for each and every category.

df["num-of-doors"].value_counts()
# Out:
# four    115
# two      86
# Name: num-of-doors, dtype: int64

# %%
#The value_counts() function counts the number of times each value appears,
#and the idxmax() function returns the index of the row with the highest value.
df["num-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
#replace the missing 'num-of-doors; values by the most frequent
df["num-of-doors"].replace(np.nan, "four", inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    2
# diesel               0
# gas                  0
# dtype: int64

# %%
#simply drop whole row with NaN in "horsepower-binned" column
df.dropna(subset=["horsepower-binned"], axis = 0, inplace = True)

#reset index, because we dropped two rows
df.reset_index(drop = True, inplace = True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# city-L/100km         0
# horsepower-binned    0
# diesel               0
# gas                  0
# dtype: int64

# %%
"""
Data Standardization :-

Data is usually collected from different agencies with different formats. (Data Standardization is also a term for a particular type of data normalization, where we subtract the mean and divide by the standard deviation)

What is Standardization?

Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.

Example:

Transform mpg to L/100km:

In our dataset, the fuel consumption columns "city-mpg" and "highway-mpg" are represented by mpg (miles per gallon) unit. Assume we are developing an application in a country that accept the fuel consumption with L/100km standard


"""

df["city-L/100km"] = 235/df["city-mpg"]
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    horsepower  peak-rpm  city-mpg  highway-mpg    price city-L/100km  \
# ...

# %%
#same for "highway-mpg" 235 is for convering mile per gallon to litre per 100kms
df["highway-L/100km"] = 235/df["highway-mpg"]
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    horsepower  peak-rpm  city-mpg  highway-mpg    price city-L/100km  \
# ...

# %%
"""
Data Normalization :-
Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1

Example:

To demonstrate normalization, let's say we want to scale the columns "length", "width" and "height"

Target:would like to Normalize those variables so their value ranges from 0 to 1.

"""

df["length"]  = df["length"] / df["length"].max()
df["height"] = df["height"] / df["height"].max()
df["width"] = df["width"] / df["width"].max()

df[["length", "height", "width"]].head()
# Out:
#      length    height     width
# 0  0.811148  0.816054  0.890278
# 1  0.811148  0.816054  0.890278
# 2  0.822681  0.876254  0.909722
# 3  0.848630  0.908027  0.919444
# 4  0.848630  0.908027  0.922222

# %%
"""
Indicator variable (or dummy variable)

An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.

Why we use indicator variables?

So we can use categorical variables for regression analysis in the later modules.

Example:

We see the column "fuel-type" has two unique values, "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.

We will use the panda's method 'get_dummies' to assign numerical values to different categories of fuel type.

"""
